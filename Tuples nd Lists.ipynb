# %%
# Creat an empty tuple
tuple()
# Out:
# ()

# %%
# Creat an empty list()
list()
# Out:
# []

# %%
tup = (1,2)
tup
# Out:
# (1, 2)

# %%
name = ("Owais", 55 + 1, 56.9, "Tuple")
name
# Out:
# ('Owais', 56, 56.9, 'Tuple')

# %%
list_items = ["owais", 55 * 2, 66, 44.2,"List"]
list_items
# Out:
# ['owais', 110, 66, 44.2, 'List']

# %%
x = (1,)
print(x)
# Out:
# (1,)

# %%
type(x)
# Out:
# tuple

# %%
x = (34)
print(type(x))
# Out:
# <class 'int'>

# %%
x = (1)
print(type(x))
# Out:
# <class 'int'>

# %%
z = 4,
z
# Out:
# (4,)

# %%
print(type(z))
# Out:
# <class 'tuple'>

# %%
a = 4,5,6,7
a
# Out:
# (4, 5, 6, 7)

# %%
print(type(a))
# Out:
# <class 'tuple'>

# %%
x = 6,7,8,9
x
# Out:
# (6, 7, 8, 9)

# %%
name = "Owais"
x = list(name)
x
# Out:
# ['O', 'w', 'a', 'i', 's']

# %%
age = "Twenty Years Old"
print(tuple(age))
# Out:
# ('T', 'w', 'e', 'n', 't', 'y', ' ', 'Y', 'e', 'a', 'r', 's', ' ', 'O', 'l', 'd')

# %%
age = "99"
print(tuple(age))
# Out:
# ('9', '9')

# %% [markdown]
# # Adding and Removing items

# %%
name = ["Owais", "Umair"]
name
# Out:
# ['Owais', 'Umair']

# %%
name.append("Aorangzaib")
name
# Out:
# ['Owais', 'Umair', 'Aorangzaib']

# %%
name.append("Shams")
name
# Out:
# ['Owais', 'Umair', 'Aorangzaib', 'Shams']

# %%
var_123 = [34,5,6,7,8,9]
var_123.append(34)
var_123
# Out:
# [34, 5, 6, 7, 8, 9, 34]

# %%
var_123.append(30)
var_123
# Out:
# [34, 5, 6, 7, 8, 9, 34, 30]

# %%
x = ("THis", "is", "new", "Item")
print(type(x))
# Out:
# <class 'tuple'>

# %%
name_Cazan = ['Shams','Aorangzaib','Shazaib']
name_Cazan.insert(0, "Janzaib")
name_Cazan
# Out:
# ['Janzaib', 'Shams', 'Aorangzaib', 'Shazaib']

# %%
name_Cazan.insert(-1, "Saif-Uddin")
name_Cazan
# Out:
# ['Janzaib', 'Shams', 'Aorangzaib', 'Saif-Uddin', 'Shazaib']

# %%
books = ['Physics','Chemistry','Biology']
books.insert(0,"Mathematics")
books
# Out:
# ['Mathematics', 'Physics', 'Chemistry', 'Biology']

# %%
books.insert(2,"Data Science")
books
# Out:
# ['Mathematics', 'Physics', 'Data Science', 'Chemistry', 'Biology']

# %%
books.pop()
# Out:
# 'Biology'

# %%
books
# Out:
# ['Mathematics', 'Physics', 'Data Science', 'Chemistry']

# %%
books.pop(1)
# Out:
# 'Physics'

# %%
books
# Out:
# ['Mathematics', 'Data Science', 'Chemistry']

# %%
books.append("Machine Learning")
books
# Out:
# ['Mathematics', 'Data Science', 'Chemistry', 'Machine Learning']

# %%
books.insert(0, "Deep Learning")
books
# Out:
# ['Deep Learning',
#  'Mathematics',
#  'Data Science',
#  'Chemistry',
#  'Machine Learning']

# %%
lits = [[]] * 4

# %%
lits
# Out:
# [[], [], [], []]
