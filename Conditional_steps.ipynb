# %%
# Movie Ticket price calculator

age = 30
if age < 15 :
    price = 5
elif age > 30:
    price = 10
else :
    price = 15

print("Age:", age)
print("Ticket Price: $", price)
# Out:
# Age: 30
# Ticket Price: $ 15

# %%
apple = 50
if apple > 80:
    print("This is for owais:", apple)

elif apple == 80:
    print("This is for the umair:", apple)
else:
    print("This is for nobody:", apple)
# Out:
# This is for nobody: 50

# %%
traffic_light = 100
if traffic_light > 90:
    print("Yes you can go now:", traffic_light)
elif traffic_light < 50:
    print("No you can't go:" traffic_light)
else:
    print

# %%
,
