# %%
n = 5
while n > 0 :
    print(n)
    n = n - 1
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
age = 30
while age > 20:
    print("you are now fit:", age)
    age = age - 1
# Out:
# you are now fit: 30
# you are now fit: 29
# you are now fit: 28
# you are now fit: 27
# you are now fit: 26
# you are now fit: 25
# you are now fit: 24
# you are now fit: 23
# you are now fit: 22
# you are now fit: 21

# %%
price = 1000
while price > 800:
    print("It's very expensive:", price)
    price = price - 10
# Out:
# It's very expensive: 1000
# It's very expensive: 990
# It's very expensive: 980
# It's very expensive: 970
# It's very expensive: 960
# It's very expensive: 950
# It's very expensive: 940
# It's very expensive: 930
# It's very expensive: 920
# It's very expensive: 910
# It's very expensive: 900
# It's very expensive: 890
# It's very expensive: 880
# It's very expensive: 870
# It's very expensive: 860
# It's very expensive: 850
# It's very expensive: 840
# It's very expensive: 830
# It's very expensive: 820
# It's very expensive: 810

# %%
n = 5
while n > 0 :
    print(n)
    n = n - 1
# Out:
# 5
# 4
# 3
# 2
# 1
